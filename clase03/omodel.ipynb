# %% [markdown]
# # Técnicas avanzadas de diseño de software
# ## Modelo de objetos de Python + Composición de objetos
#
# ![image.png](attachment:image.png)
#
# <small><b>Source:</b> <a href="https://dbader.org/blog/python-dunder-methods">https://dbader.org/blog/python-dunder-methods</a></small>

# %% [markdown]
# ## Python Data types
# -----
#
# Sean las listas y nd-arrays dos objetos secuencia en Python

# %%
[1, 2, 3] + [4, 5, 6] # ob.m(c)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# Funciona distinto de esto

# %%
import numpy as np

np.array([1, 2, 3]) + 1
# Out:
# array([2, 3, 4])

# %% [markdown]
# ## Python Data types
# -----
#
# al igual que estas dos cosas

# %%
np.array([1, 2, 3]) * 2
# Out:
# array([2, 4, 6])

# %%
[1, 2, 3] * 2
# Out:
# [1, 2, 3, 1, 2, 3]

# %% [markdown]
# ## Python Data types
# -----
# O una de estas directamente no funciona

# %%
np.array([1, 2, 3]) + 1
# Out:
# array([2, 3, 4])

# %%
[1, 2, 3] + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 [1, 2, 3] + 1
#
# TypeError: can only concatenate list (not "int") to list

# %% [markdown]
# ### Dunders
# ----
#
# - Por que funciona esto?

# %%
len([1])
# Out:
# 1

# %%
1 + 17
# Out:
# 18

# %%
def foo():
    return "hello"

foo()
# Out:
# 'hello'

# %% [markdown]
# ### Dunders
# ----
#
# Vamos con el ejemplos simple

# %%
class HasLen:
    def __init__(self, l):
        self.l = l
    def __len__(self):
        return self.l

# %%
foo = HasLen(l=45454542)
len(foo)
# Out:
# 45454542

# %%
foo.__len__()
# Out:
# 45454542

# %% [markdown]
# ### Dunders
# ----
#
# - En Python, los métodos especiales son un conjunto de métodos predefinidos que se puede usar para enriquecer las clases. Son fáciles de reconocer porque comienzan y terminan con guiones bajos dobles, por ejemplo `__init__` o `__str__`.
#
# - Como es cansador decir  *under-under-method-under-under* la comunidad empezo a decirles **dunder** contraccion de *double-under*.
#
# - Los métodos Dunder le permiten emular el comportamiento de los tipos integrados. Por ejemplo, para obtener la longitud de una cadena puede llamar a `len('cadena')`.

# %% [markdown]
# ### Dunders
# ----
#
# Inicialización

# %%
class Account:
    """A simple account class"""

    def __init__(self, owner, amount=0):
        """This is the constructor that lets us create
        objects from this class.

        """
        self.owner = owner
        self.amount = amount
        self._transactions = []

    def add_transaction(self, amount):
        if not isinstance(amount, int):
            raise ValueError('please use int for amount')
        self._transactions.append(amount)

    @property
    def balance(self):
        return self.amount + sum(self._transactions)

# %% [markdown]
# ### Dunders
# ----
#
# Representación

# %%
Account("juan", 100)

# %%
Account.mro()
# Out:
# [__main__.Account, object]

# %%
class Account(Account):

    def __repr__(self):
        return f'{type(self).__name__}({self.owner}, {self.amount})'

    def __str__(self):
        return f'Account of {self.owner} with starting amount: {self.amount}'

# %%
acc = Account('bob', 10)
acc
# Out:
# Account(bob, 10)

# %%
repr(acc)
# Out:
# 'Account(bob, 10)'

# %% [markdown]
# ### Dunders
# ----
#
# Iteración

# %%
class Account(Account):

    def __len__(self):
        return len(self._transactions)

    def __getitem__(self, position):
        return self._transactions[position]

    def __setitem__(self, pos, v):
        self._transactions[pos] = v

# %%
acc = Account('bob', 10)
acc.add_transaction(20)
acc.add_transaction(-10)
acc.add_transaction(50)
acc.add_transaction(-20)
acc.add_transaction(30)

acc.balance
# Out:
# 80

# %% [markdown]
# ### Dunders
# ----
#
# Iteración

# %%
len(acc)
# Out:
# 5

# %%
acc[2]
# Out:
# 50

# %%
acc.balance
# Out:
# 80

# %%
for t in acc:
    print(t)
# Out:
# 20
# -10
# 50
# -20
# 30

# %%
class A:
    def __getitem__(self, i):
        return "hola benja"

A()[12]
# Out:
# 'hola benja'

# %% [markdown]
# ### Dunders
# ----
#
# Comparación
#
# Los métodos son siempre con `__` al comienzo y al final: `ge, gt, le, lt, eq, ne`
# Pero a partir de `__eq__` y algun otro se pueden completar automaticamente los demas con un decorador.

# %%
import functools

@functools.total_ordering
class Account(Account):
    # ... (see above)

    def __eq__(self, other):
        return self.balance == other.balance

    def __lt__(self, other):
        return self.balance < other.balance

# %%
acc2 = Account('tim', 100)
acc2.add_transaction(20)
acc2.add_transaction(40)
acc2.balance
# Out:
# 160

# %% [markdown]
# ### Dunders
# ----
#
# Comparación

# %%
acc2 > acc
# Out:
# True

# %%
acc2 == acc  # acc2.__eq__(acc)
# Out:
# False

# %%
acc2 >= acc
# Out:
# True

# %% [markdown]
# ### Dunders
# ----
#
# Aritmética
#
# Los métodos son siempre con `__` al comienzo y al final: `add, diff, mult, div, pow`, etc.

# %%
class Account(Account):

    def __add__(self, other):
        cls = type(self)
        owner = f"{self.owner} + {other.owner}"
        start_amount = self.balance + other.balance
        return cls(owner, start_amount)

class Coso(Account): pass

# %%
acc2 = Account("tim", 200)
acc2.balance
acc2
# Out:
# Account(tim, 200)

# %%
acc3 = acc2 + acc
acc3
# Out:
# Account(tim + bob, 280)

# %% [markdown]
# ### Dunders
# ----
#
# Objetos ejecutablles/llamables/callables

# %%
class Account(Account):
    # ... (see above)

    def __call__(self, c):
        print('Start amount: {}'.format(self.amount))
        print(c)
        print('Transactions: ')
        for transaction in self:
            print(" - ", transaction)
        print('\nBalance: {}'.format(self.balance))

# %%
acc2 = Account("tim", 200)
acc2.add_transaction(10)
acc2.add_transaction(100)
acc2.balance;

# %%
acc2;

# %%
callable(acc2)
# Out:
# True

# %% [markdown]
# ### Dunders Final
# -------------
#
# Hay muchos mas magic methods, pero eso se los dejo ver segun haga falta https://rszalski.github.io/magicmethods/

# %%
import pandas as pd
class A(object):
    def __init__(self, nombre):
        super().__setattr__("nombre", nombre)
        super().__setattr__("_data", {})

    def __getattr__(self, n):
        return self._data.get(n, "<UNK>")

    def __setattr__(self, n, v):
        self._data[n] = v

    def m(self):
        return 43

a = A("tito")
a.m()
# Out:
# 43

# %% [markdown]
# ### Duck Typing vs Polimorfismo por Coerción
#
# **Duck Typing:**
# - Basado en comportamiento, no en tipo
# - No implica conversión de tipos
# - Común en lenguajes dinámicos (ej. Python)
#
# ```python
# def nadar(animal):
#     animal.nadar()  # Funciona para cualquier objeto con método nadar()
# ```
#
# **Polimorfismo por Coerción:**
# - Implica conversión implícita de tipos
# - El sistema realiza la conversión automáticamente
# - Presente en muchos lenguajes
#
# ```python
# print(len("hola") + 1)  # 5 (string coercionado a int)
# ```
#
# **Relación:**
# - Duck typing puede simular coerción en algunos casos
# - En Python, muchas operaciones que parecen coerción son realmente duck typing
#
# ```python
# class FakeNumber:
#     def __add__(self, other):
#         return 42
#
# print(1 + FakeNumber())  # 42 (parece coerción, pero es duck typing)
# ```

# %% [markdown]
# ## Paquete interesante Sh
# https://amoffat.github.io/sh/

# %%
import sh

# %%
sh.ls()
# Out:
# 'decoradores.ipynb  meta.ipynb  omodel.ipynb  pattern_matching.ipynb  rise.css\n'

# %% [markdown]
# ## Composición
#
# Usando los *dunders* podemos delegar mensajes que no sabemos como responder en nuestra clase a un objeto subyacente
#
# - Que pasa si comento `__repr__`
# - Por qué `__str__` funciona igual si no lo redefiní en mi DataFrame?
# - Por qué anda distinto el `repr()` en notebook respecto a la consola?
# - Por que no anda el `__getattr__()` con dunders?

# %%
import pandas as pd

# %%
class MiDataFrame:

    def __init__(self, df):
        self._df = df

    def zaraza(self):
        return 1

    def __getitem__(self, slice):
        return self._df.__getitem__(slice)

    def __getattr__(self, a):
        return getattr(self._df, a)

    def __repr__(self):
        return repr(self._df)


df = MiDataFrame(pd.DataFrame({"a": [1,2,3], "b": [4,5,6], "c": [7,8,9.]})  )
df
# Out:
#    a  b    c
# 0  1  4  7.0
# 1  2  5  8.0
# 2  3  6  9.0

# %%
print(str(df))
# Out:
#    a  b    c
# 0  1  4  7.0
# 1  2  5  8.0
# 2  3  6  9.0
