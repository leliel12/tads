# %% [markdown]
# # Técnicas avanzadas de diseño de software
#
# ## Code Smells
#
# ### (Poner autores aca)
#
# PONER IMAGEN LINDA

# %% [markdown]
# # Borrar esta slide con consideraciones
#
# Usen lo que sea necesario para armar una clase de más o menos 40 minutos alrededor de la arquitectura de esta librería.
#
# Usen la utilidad jupyter rise para hacer esta charla: si instalaron según el readme tienen todo disponible.
#
# ### Todo lo que sigue es parte de una thesis de maestria
#
# - Un catalogo online que **no anda** con firefox: https://luzkan.github.io/smells/
# - La thesis: https://github.com/Luzkan/smells/blob/main/docs/thesis.pdf
# - Las fuentes de todo: https://github.com/Luzkan/smells/tree/main?tab=readme-ov-file
#
# ### Mas info
#
# - Esto es un review de la literatura para que se ordenen en que esta la gente investigando sobre este tema [Code smells: A Synthetic Narrative Review
# ](https://arxiv.org/abs/2103.01088)
#
# - Un blogpost con un resumen[Code Smells: A Solution Architects’s Guide](https://solutionsarchitecture.medium.com/code-smells-a-solution-architectss-guide-c58adb3f45d2)
#
#
# ## Les recomiendo una estructura del estilo
#
# 1. Introducción a los Code Smells
# 2. Taxonomía y categorización de Code Smells
# 3. Code Smells más comunes y cómo resolverlos
# 4. Detección y refactorización
# 5. Aplicación práctica y conclusiones
#
# **Recueden es una clase, van a preguntarles mas de lo que muestran**
