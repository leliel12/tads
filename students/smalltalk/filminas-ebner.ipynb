# %% [markdown]
# # Mensajes
# ![image.png](attachment:457ffde1-9afd-472c-a09f-e8cbeabbd5f6.png)
#
# - Los objetos colaboran entre ellos a travez de mensajes. De hecho no existen operadores, solo mensajes.
# - Los mensajes tienen 3 tipos **unarios**, **binarios** y **keywords**

# %% [markdown]
# # Mensajes
# ## Estructura de Mensajes
#
# Usaremos la siguiente terminologia al hablar de los mensajes:
# <div style="max-width:700px;margin: auto;">
#
# ![image.png](attachment:6421b535-55e4-43ae-a1d4-d837f7b76c9f.png)
#
# </div>
#
#
# En castellano, podemos sacar la siguiente informacion
# - Un mensaje esta compuesto de un selector y opcionalmente argumentos
# - Un mensaje siempre se le envia a un receptor, este puede ser un literal, un bloque, una variable o el resultado de evaluar otro mensaje.
# - La combinacion de mensaje y receptor se llama *envio de mensaje*

# %% [markdown]
# # Mensajes
# ##  Mensajes unarios
#
# - Los **mensajes unarios** son mensajes que no requieren ningun argumento. Son todos de la forma `reciver messageName`.
# ```smalltalk
# 89 sin
# >>> 0.860069405812453
#
# 3 sqrt
# >>> 1.732050807568877
#
# Float pi
# >>> 3.141592653589793
#
# 'blop' size
# >>> 4
#
# true not
# >>> false
# ```

# %% [markdown]
# # Mensajes
# ## Mensajes binarios
#
# - Los **mensajes binarios** son mensajes que requieren exactamente un argumento y su selector consiste en una secuencia de uno o mas caracteres del conjunto `{+, -, *, /, &, =, >, |, <, ~, @}`.
#
# ```smalltalk
# 100@100
# >>> 100@100 "creates a Point object"
#
# 3 + 4
# >>> 7
#
# 10 - 1
# >>> 9
#
# 4 <= 3
# >>> false
#
# (4/3) * 3 == 4
# >>> true "equality is just a binary message, and Fractions are exact"
#
# (3/4) == (3/4)
# >>> false "two equal Fractions are not the same object"
# ```

# %% [markdown]
# # Mensajes
# ## Mensajes keyword
#
# - Los **mensajes keyword** son mensajes que requieren uno o mas argumentos y su selector consiste en una o mas *palabras clave* terminadas en dos puntos, es decir son de la forma `receiver selectorWordOne: argumentOne wordTwo: argumentTwo ... wordN: argumentN`
#
#
# ```smalltalk
# 2 between: 0 and: 10
# >>> true
# ```
# En el ejemplo anterior, el selector del mensaje es `between:and:`
#
# ```smalltalk
# Color r:1 g:0 b:0
# >>> Color red
# ```
#
# A modo de ejemplo, en la sitaxis de Java el *mensaje enviado* anterior se corresponde a `Color.rgb(1,0,0)`
#
#
# ```smalltalk
# 1 to: 10
# >>> (1 to: 10) "creates an interval"
#
# | nums |
# nums := Array newFrom: (1 to: 5).
# nums at: 1 put: 6.
# nums
# >>> #(6 2 3 4 5)
# ```

# %% [markdown]
# # Mensajes
# ## Composicion y precedencia
# Los 3 tipos de mensajes tienen distinta precedencia, lo que nos ayuda a poder componerlos de una manera simple y elegante.
#
# A tener en cuenta:
# 1. Los mensajes *unarios* siempre se envian primero, luego los mensajes *binarios* y por ultimo los mensajes *keyword*.
# 2. Los mensajes en parentesis se envian primero a todo tipo de mensajes.
# 3. Los mensajes del mismo tipo se evaluan de izquierda a derecha.
#
# Es decir podemos hacer cosas como
# ```smalltalk
# 1000 factorial / 999 factorial "en vez de (1000 factorial)/ (999 factorial)"
# >>> 1000
#
# 2 raisedTo: 1 + 3 factorial "en vez de 2 (raisedTo: (1 + (3 factorial)))"
# >>> 128
# ```

# %% [markdown]
# # Mensajes
# ## Composicion y precedencia
#
# Esta bueno
#
# ```smalltalk
# 3 + 4 * 5
# >>> ?
# ```

# %% [markdown]
# # Mensajes
# ## Composicion y precedencia
#
# Esta bueno, pero hay que tener cuidado
# ```smalltalk
# 3 + 4 * 5
# >>> 35 "(not 23) Binary messages sent from left to right"
# 3 + (4 * 5)
# >>> 23
# ```

# %% [markdown]
# # Mensajes
# ## Composicion y precedencia
#
# Esta bueno, pero hay que tener cuidado
# ```smalltalk
# 1 + 1/3
# >>> ?
# ```

# %% [markdown]
# # Mensajes
# ## Composicion y precedencia
#
# Esta bueno, pero hay que tener cuidado
# ```smalltalk
# 1 + 1/3
# >>> (2/3) "and not 4/3"
#
# 1 + (1/3)
# >>> (4/3)
# ```

# %% [markdown]
# # Mensajes
# ## Composicion y precedencia
#
# Esta bueno, pero hay que tener cuidado
# ```smalltalk
# 1/3 + 2/3
# >>> ?
# ```

# %% [markdown]
# # Mensajes
# ## Composicion y precedencia
#
# Esta bueno, pero hay que tener cuidado
# ```smalltalk
# 1/3 + 2/3 "((1/3) + 2) / 3"
# >>> (7/9) "and not 1"
#
# (1/3) + (2/3)
# >>> 1
# ```

# %% [markdown]
# # Mensajes
# ## Composicion y precedencia
#
# Esta bueno, pero hay que tener cuidado
# ```smalltalk
# 5 + 3 squared
# >>> ?
# ```

# %% [markdown]
# # Mensajes
# ## Composicion y precedencia
#
# Esta bueno, pero hay que tener cuidado
# ```smalltalk
# 5 + 3 squared
# >>> 14 "3 squared = 9, luego 5 + 9"
#
# (5 + 3) squared
# >>> 64 "Aquí suma primero: (5 + 3) = 8, luego 8 squared = 64"
# ```

# %% [markdown]
# # Mensajes
# ## Composicion y precedencia
#
# Esta bueno, pero hay que tener cuidado
# ```smalltalk
# 3 + 4 * 5
# >>> 35 "(not 23) Binary messages sent from left to right"
#
# 3 + (4 * 5)
# >>> 23
#
# 1 + 1/3
# >>> (2/3) "and not 4/3"
#
# 1 + (1/3)
# >>> (4/3)
#
# 1/3 + 2/3
# >>> (7/9) "and not 1"
#
# (1/3) + (2/3)
# >>> 1
#
# 5 + 3 squared
# >>> 14 "3 squared = 9, luego 5 + 9"
#
# (5 + 3) squared
# >>> 64 "Aquí suma primero: (5 + 3) = 8, luego 8 squared = 64"
# ```

# %% [markdown]
# # Sintaxis
# ## Playground y Transcript
# Para hacer la demostracion de la proxima parte vamos a usar dos herramientas dentro de Pharo:
#
# - **Playground**: Es un espacio en Pharo donde puedes escribir, probar e inspeccionar código de forma rápida y sencilla. (como un replit)
#
# - **Transcript**: Es una ventana que muestra mensajes o resultados de salida, útil para registrar información mientras se ejecuta el programa. (como un stdout)
#
#
# ![image.png](attachment:f616786c-904e-4208-9efa-812f5d3b5ee0.png)

# %% [markdown]
# # Sintaxis
# ## Variables
# - Las variables se definen entre pipes o plecas `|`.
# - La asignacion es con `:=` y la comparacion es con`=`
#
#
# ![image.png](attachment:f9151c49-509a-499a-a65d-fd0c2faafecf.png)

# %% [markdown]
# # Sintaxis
# ## Variables
# - Las variables se definen entre pipes o plecas `|`.
# - La asignacion es con `:=` y la comparacion es con`=`
#
#
# ![image.png](attachment:a5b09efb-4bf3-4558-b2f8-987395f516ad.png)

# %% [markdown]
# # Sintaxis
# # Pseudovariables
#
# En pharo hay 6 pseudovariables
# 1. `nil`
# 2. `true`
# 3. `false`
# 4. `self`
# 5. `super`
# 6. `thisContext`
#
# Se llaman pseudovariables porque estan predefinidas y no se les puede asignar otro valor.
#
# Las variables `true`, `false`, y `nil` son constantes, mientras que `self`, `super` y `thisContext` varian dinamicamente mientras el codigo se ejecuta.

# %% [markdown]
# # Sintaxis
# ## Bloques
# - Un bloque es esencialmente una funcion anonima o expresion lambda.
# - Se ejecuta enviandole el mensaje `value`.
# - El bloque responde con la ultima expresion en su cuerpo a no ser que haya un retorno explícito (con `^`) en cuyo caso retorna con la expresion devuelta.
#
# ![image.png](attachment:561c256e-1994-4af0-b3d4-f8b299cd12be.png)

# %% [markdown]
# # Sintaxis
# ## Bloques
# - Los bloques pueden tener parametros, cada uno es declarado de la forma `:param`, separados por un pipe (`|`).
# - Tambien pueden tener variables locales, estas se definen entre pipes (`|`).
#
# ![image.png](attachment:dfeca058-c3b3-4fcc-9f6d-400e149ce5f5.png)

# %% [markdown]
# # Sintaxis
# ## Estructuras de control
#
# - Los condicionales son expresados enviando uno de los mensajes `ifTrue:`, `ifFalse:`, `ifTrue:ifFalse:`, `ifFalse:ifTrue:` al resultado de un expresion booleana.
#
# ![image.png](attachment:9bc03ae6-e4e6-4d64-8ac3-8334b156b333.png)

# %% [markdown]
# # Sintaxis
# ## Estructuras de control
# - Los ciclos son expresados enviando mensajes a bloques, enteros o colecciones.
# - Dado que la condicion de salida de un bloque podria ser evaluada multiples veces debe ser un bloque en lugar de una expresion booleana
#
# Algunos ejemplos de bloques son
#
# - `... timesRepeat: [ ... ].`
# - `[ ... ] whileTrue: [ ... ].`
# - `[ ... ] whileFalse: [ ... ].`
#
# <div style="max-width:1000px;margin: auto;">
#
# ![image.png](attachment:55826184-69c0-41a0-a71a-a7cae1c32758.png)
#
# </div>
#
# Tambien podemos enviarle el mensaje `to:do:` a un numero, esto actua como el inicio de contador.
# <div style="max-width:1000px;margin: auto;">
#
# ![image.png](attachment:b5a373ef-07de-4983-aca5-39d4cbe9c6aa.png)
#
# </div>

# %% [markdown]
# # Sintaxis
# ## Arrays
# - Un array es una colección de tamaño **fijo** a la que se puede acceder mediante indices.
# - La forma para acceder a los elementos del array es a travez del mensaje `at:` y `at:put:`.
#
# **IMPORTANTISIMO:** los indices en Pharo empiezan en 1 💀☠️
#
# ![image.png](attachment:b112afa4-19d6-422f-8ba6-29365fd335a8.png)
#
#
# - Podemos crear arrays de distintas formas
# ```smalltalk
# #(4 4/6 'Pepe') size
# >>> 3
#
# Array with: 4 with: 'Hola' with: 3/2
# >>> {4. 'Hola'. (3/2)}
# ```

# %% [markdown]
# # Sintaxis
# ## OrderedCollection
# - Es una de las colecciones que puede expandirse.
# - Ofrece mensajes como `add:"`, `addFirst:`, `addLast:` y `addAll:`
# ```smalltalk
# | ordCol |
# ordCol := OrderedCollection new.
# ordCol add: 'C++'; add: 'Python'; addFirst: 'SmallTalk'.
# ordCol
# >>> an OrderedCollection('SmallTalk' 'C++' 'Python')
# ```
# - Tambien podemos eliminar objetos
#
# ```smalltalk
# ordCol add: 'Rust'.
# ordCol remove: 'Rust'.
# ordCol
# >>> an OrderedCollection('SmallTalk' 'C' 'Python')
# ```

# %% [markdown]
# # Sintaxis
# ## Muchos otras colecciones
#
# Hay muchos otras implementaciones de colecciones, cada una con sus mensajes:
# - Interval
# - Dictionary
# - IdentityDictionary
# - Set
# - SortedCollection
# - Strings

# %% [markdown]
# # Sintaxis
# ## Tarjeta postal
# Se supone que la sintaxis de Smalltalk es tan **simple** y **facil** de entender que entra en una *tarjeta postal* o *post card*
#
# ![image.png](attachment:3921f307-6d2e-48a8-a381-995ed066b5c3.png)

# %% [markdown]
# # Sintaxis
# ## Tarjeta postal
# Y la version actualizada (de Pharo) es la siguiente
#
#
# ![image.png](attachment:b922fd99-fed7-415b-abda-286161e4235c.png)
