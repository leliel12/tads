# %% [markdown]
# # Técnicas avanzadas de diseño de software
#
# ## Frameworks de cómputo distribuido
#
# ### (Poner autores aca)
#
# PONER IMAGEN LINDA

# %% [markdown]
# # Borrar esta slide con consideraciones
#
# Usen lo que sea necesario para armar una clase de más o menos 40 minutos
#
# Usen la utilidad jupyter rise para hacer esta charla: si instalaron según el readme tienen todo disponible.
#
#
#
# - Tengan en cuenta que el chiste de la clase es como usar grafos para hacer computo distribuido
# - Aca ta la vieja charla de dask del curso anterior: https://github.com/leliel12/diseno_sci_sfw/blob/2024/04_optimizacion/02_dask.ipynb
# - Muestren tambien el tema de actores y dask
# - comparen con Ray, Spark. Tambien hay uno que se llama prefect
# - De eso no tengo material pero hay mas charlas que el cuerno en pyvideo
# - Expliquen en que caso se prefieren
# - HAy una forma de usar los schedulers de dask en joblib
#
# **Recueden es una clase, van a preguntarles mas de lo que muestran**
