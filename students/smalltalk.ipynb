# %% [markdown]
# # Técnicas avanzadas de diseño de software
#
# ## Orientación a Objetos Pura: Pharo-Smalltalk
#
# ### -
#
# ![image.png](attachment:13245a74-8bcd-4d96-9731-1b7c848b8624.png)

# %% [markdown]
# # Esta slide pueden borrarla
#
# - Vean esta charla: https://www.youtube.com/watch?v=baxtyeFVn3w&ab_channel=LambdaWorld
# - Fijense como esta implementado los booleanos y el if-else (o como no esta implementado)
# - Expliquen el numero de la revista byte tiene insight interesante
