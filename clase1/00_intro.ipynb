# %% [markdown]
# # Técnicas avanzadas de diseño de software
#
# ## Intro y filosofía de la materia
#
# ![image.png](attachment:273ba510-413e-4742-ad08-b339e3e12acd.png)

# %% [markdown]
# # **LOGISTICA**
#
# * **Cuando?** Lunes y Miércoles de 14hs a 18hs
# * **Dónde?**
#    * **Clases presenciales:** en el Aula 13.
#    * **Asistencia obligatoria**
# * **Como?** ~2 hs de teórico + ~2 hs de práctico exposición.
# * **Canales Oficiales de Comunicación:**
#    * **Zulip:** `#TADS`
#    * **Repo:** https://github.com/leliel12/tads
#
# ![image.png](attachment:5c4d7b57-3bf2-45b2-81e7-35d0ee456783.png)

# %% [markdown]
# # EVALUACIÓN
#
# - **Para Regularizar:**
#   - Todas las clases dos/pareja/2 personas van a exponer algún tema.
#   - Va a haber un práctico grupal.
# - **Examen Final:**
#   - Estar regular.
#   - Práctico grupal diseñando una herramienta.
#   - Se presenta con un informe, documentación, testing, coverage y estilo uniforme.
#
# **Pueden hacer el trabajo final de carrera con el práctico**

# %% [markdown]
# # OBJETIVOS DEL CURSO
#
# - Entender qué consecuencias trae un mal diseño (saber dónde se meten con sus decisiones)
# - Dar el conocimiento mínimo para que puedan explorar el área (Necesitamos mucho más tiempo para entrar en detalle)
# - Analizar el estado del arte en la ingeniería de diseñar software (La pesadilla que nos está llevando la IA)
# - Discutir mucho.
# - Tomar mate y comer criollitos

# %% [markdown]
# # FILOSOFÍA
#
# * Vamos a hablar de fundamentos.
# * Vamos a hablar de física.
# * Vamos a hablar de economía.
# * Vamos a hablar "algo" de psicología.
# * Vamos a discutir con y sin números (Dato mata relato).
# * Me comprometo a dar un kickoff a la discusión y ustedes se comprometen a hablar.

# %% [markdown]
# # Somos chefs, no cocineros
#
# ![image.png](attachment:1b002374-5973-4a72-93b3-047ed1f585a2.png)
